# %%
import pandas as pd
import numpy as np
import arimafd as oa

my_array = np.random.normal(size=1000) # init array
my_array[-3] = 1000 # init anomaly
ts = pd.DataFrame(my_array,
                  index=pd.date_range(start='16-04-2025',
                                      periods=1000,
                                      freq='H'))

my_arima = oa.Arima_anomaly_detection(ar_order=3)
my_arima.fit(ts[:500])
ts_anomaly = my_arima.predict(ts[500:])


# or you can use for streaming:
# bin_metric = []
# for i in range(len(df)):
#     bin_metric.append(my_arima.predict(df[i:i+1]))
# bin_metric = pd.concat(bin_metric)
# bin_metric

# for evaluating results you can use https://tsad.readthedocs.io/en/latest/Evaluating.html 
ts_anomaly
# Out:
# C:\Users\Uttu\AppData\Local\Temp\ipykernel_11544\2131042946.py:8: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   index=pd.date_range(start='16-04-2025',
# Time seconds: 0.6142656803131104
# 2025-05-06 20:00:00    0
# 2025-05-06 21:00:00    0
# 2025-05-06 22:00:00    0
# 2025-05-06 23:00:00    0
# 2025-05-07 00:00:00    0
#                       ..
# 2025-05-27 11:00:00    0
# 2025-05-27 12:00:00    0
# 2025-05-27 13:00:00    0
# 2025-05-27 14:00:00    1
# 2025-05-27 15:00:00    1
# Freq: h, Length: 500, dtype: int32

# %%
my_array = np.random.normal(size=1000) # init array
my_array[-3] = 1000 # init anomaly
ts = pd.DataFrame(my_array,
                  index=pd.date_range(start='01-01-2000',
                                      periods=1000,
                                      freq='H'))
ad = oa.anomaly_detection(ts) #init anomaly detection algorithm
ad.generate_tensor(ar_order=3) #it compute weights of ARIMA on history 
ts_anomaly = ad.proc_tensor() #processing of weights. 
# ad.ebeluate_nab() # function for evaluating results of algorithms
ts_anomaly
# Out:
# C:\Users\Uttu\AppData\Local\Temp\ipykernel_11544\2905133375.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   index=pd.date_range(start='01-01-2000',
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 7
#       2 my_array[-3] = 1000 # init anomaly
#       3 ts = pd.DataFrame(my_array,
#       4                   index=pd.date_range(start='01-01-2000',
#       5                                       periods=1000,
#       6                                       freq='H'))
# ----> 7 ad = oa.anomaly_detection(ts) #init anomaly detection algorithm
#       8 ad.generate_tensor(ar_order=3) #it compute weights of ARIMA on history
#       9 ts_anomaly = ad.proc_tensor() #processing of weights.
#
# AttributeError: module 'arimafd' has no attribute 'anomaly_detection'
